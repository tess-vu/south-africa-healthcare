# %%
import geopandas as gpd
import osmnx as ox

import pandas as pd
sal= pd.read_csv('../pop_pred_final.csv')
phm=pd.read_csv('../../PHARMACIES_places_full_results.csv')

# %%
salpoint=gpd.read_file('../../2011_census/2011_Census/2011_ea_sal_centroids_kzn_gp.dbf')
salpoly=gpd.read_file('../../2011_census/2011_Census/ea_sal_kzn_gp.dbf')

# %%
# kzndrive=ox.load_graphml('../../networks/network_kwazulu_natal_drive.graphml')
# gauwalk=ox.load_graphml('../../networks/network_gauteng_walk.graphml')
# gaudrive=ox.load_graphml('../../networks/network_gauteng_drive.graphml')

# %%
pharm_gdf = gpd.GeoDataFrame(
    phm,
    geometry=gpd.points_from_xy(phm['lng'], phm['lat']),
    crs="EPSG:4326"  # WGS84
)
pharm_gdf = pharm_gdf.to_crs(salpoly.crs)

# %%
pharm_with_sal = gpd.sjoin(
    pharm_gdf,
    salpoly[['EA_CODE', 'EA_GTYPE', 'geometry']],
    how='left',
    predicate='within'
)

# %%
gdf_na_or_empty = pharm_with_sal[pharm_with_sal.geometry.isna() | pharm_with_sal.geometry.is_empty]
gdf_na_or_empty
# Out:
# Empty GeoDataFrame
# Columns: [raw_row_id, pharmacy_id, practice_num, practice_name, address, city, province, phone, query_string, http_status, api_status, place_id, matched_name, matched_address, lat, lng, types, raw_error, needs_review, filled_from_hospital, geometry, index_right, EA_CODE, EA_GTYPE]
# Index: []
#
# [0 rows x 24 columns]

# %%
sal = sal.merge(
    salpoint[["EA_CODE", "PR_NAME", 'geometry']],
    on="EA_CODE",
    how="left"
)
sal = gpd.GeoDataFrame(sal, geometry="geometry")
# Out:
# C:\Users\kalmanj\AppData\Local\Temp\ipykernel_13792\3307617542.py:1: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   sal = sal.merge(

# %%
# def assign_catchment(row):
#     if row['EA_GTYPE'] == 'Urban':
#         return 0.5 * 1609.34
#     elif row['EA_GTYPE'] == 'Traditional':
#         return 5 * 1609.34
#     else:
#         return 15 *1609.34

# sal['catchment'] = sal.apply(assign_catchment, axis=1)
# pharm_with_sal['catchment'] =5 * 1609.34

# %%
# pharm_with_sal = pharm_with_sal[
#     pharm_with_sal.geometry.x.notna() &
#     pharm_with_sal.geometry.y.notna()
# ]

# %%
kznsal = sal[sal["PR_NAME"] == "KwaZulu-Natal"].copy()
gausal = sal[sal["PR_NAME"] == "Gauteng"].copy()

# %%
kznpharm= pharm_with_sal[pharm_with_sal["province"] == "KwaZulu-Natal"].copy()
gaupharm = pharm_with_sal[pharm_with_sal["province"] == "Gauteng"].copy()

# %%
# kznwalk=ox.load_graphml('../../networks/network_kwazulu_natal_walk.graphml')

kznwalk = ox.project_graph(kznwalk)
kznwalk.graph["crs"]
# Out:
# <Projected CRS: EPSG:32761>
# Name: WGS 84 / UPS South (N,E)
# Axis Info [cartesian]:
# - N[north]: Northing (metre)
# - E[north]: Easting (metre)
# Area of Use:
# - name: Southern hemisphere - south of 60°S onshore and offshore - Antarctica.
# - bounds: (-180.0, -90.0, 180.0, -60.0)
# Coordinate Operation:
# - name: Universal Polar Stereographic South
# - method: Polar Stereographic (variant A)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Kwazulu Natal Walk Analysis 
# Walk Catchment: 2km (2000m) (1.25mi)
# Pharmacy Population Demand Catchment: 8km (8000m) (5mi)

# Pharmacy Supply: 5000/catchment pop (we must assume equal supply accross pharamcies due to limited data)

#Pharmacy Catchment Population Distribution
# mean      681.922009
# std       585.490022
# min         0.000000
# 25%       398.265719
# 50%       642.756608
# 75%       819.792569
# max      6519.646647

# %%
import osmnx as ox
import networkx as nx
from tqdm import tqdm


kznsal = kznsal.to_crs(kznwalk.graph["crs"])
kznpharm = kznpharm.to_crs(kznwalk.graph["crs"])

# %%
# ----------------------------
# GRAPH TRUNCATION
(maxy, miny, maxx, minx) = kznsal.total_bounds 
bbox = (maxy, miny, maxx, minx)

kznwalk = ox.truncate.truncate_graph_bbox(kznwalk, bbox)

# %%
# NODE ASSIGNMENT
# ----------------------------
kznsal["node"] = ox.nearest_nodes(
    kznwalk,
    kznsal.geometry.x,
    kznsal.geometry.y
)

pharm_gdf = kznpharm.copy()
pharm_gdf = pharm_gdf[
    pharm_gdf.geometry.x.notna() &
    pharm_gdf.geometry.y.notna()
]

pharm_gdf["node"] = ox.nearest_nodes(
    kznwalk,
    pharm_gdf.geometry.x,
    pharm_gdf.geometry.y
)

# %%
# ----------------------------
# STEP 1: Rj (SUPPLY SIDE)
# ----------------------------
Rj_list = []

for idx, pharm in tqdm(pharm_gdf.iterrows(), total=len(pharm_gdf)):

    lengths = nx.single_source_dijkstra_path_length(
        kznwalk,
        pharm["node"],
        cutoff=8000, 
        weight="length"
    )

    reachable_nodes = set(lengths.keys())

    nearby_pop = kznsal[kznsal["node"].isin(reachable_nodes)]

    total_pop = nearby_pop["sal2023_est"].sum()

    Rj = 5000 / total_pop if total_pop > 0 else 0  

    Rj_list.append(Rj)

pharm_gdf = pharm_gdf.reset_index(drop=True)
pharm_gdf["Rj"] = Rj_list
# ----------------------------
# STEP 2: Ai (DEMAND SIDE)
# ----------------------------
Ai_list = []

for idx, pop in tqdm(kznsal.iterrows(), total=len(kznsal)):

    lengths = nx.single_source_dijkstra_path_length(
        kznwalk,
        pop["node"],
        cutoff=2000, 
        weight="length"
    )

    reachable_nodes = set(lengths.keys())

    nearby_pharm = pharm_gdf[pharm_gdf["node"].isin(reachable_nodes)]

    Ai = nearby_pharm["Rj"].sum()

    Ai_list.append(Ai)

kznsal["Ai_walk"] = Ai_list
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1757/1757 [01:22<00:00, 21.20it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 15539/15539 [00:36<00:00, 420.94it/s]

# %%
kznsal["Ai_walk"].describe()
# Out:
# count    15539.000000
# mean         0.126348
# std          0.423924
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.022032
# max          5.714225
# Name: Ai_walk, dtype: float64

# %%
nearby_pop["sal2023_est"].describe()
# Out:
# count     263.000000
# mean      681.922009
# std       585.490022
# min         0.000000
# 25%       398.265719
# 50%       642.756608
# 75%       819.792569
# max      6519.646647
# Name: sal2023_est, dtype: float64

# %%
#--------------------------
# Kwazulu Natal Road Analysis 


# Drive Catchment: 8km (8000m)(5mi)
# Pharmacy Population Demand Catchment: 8km (8000m) (5mi)

# Pharmacy Supply: 5000/catchment pop (we must assume equal supply accross pharamcies due to limited data)

# Pharmacy Catchment Population Distribution
# mean      655.514987
# std       474.813346
# min         0.000000
# 25%       367.932790
# 50%       631.964104
# 75%       810.846952
# max      2696.998560

# %%
kzndrive=ox.load_graphml('../../networks/network_kwazulu_natal_drive.graphml')

# %%
kzndrive = ox.project_graph(kzndrive)
kznsal = kznsal.to_crs(kzndrive.graph["crs"])
kznpharm = kznpharm.to_crs(kzndrive.graph["crs"])

# %%
# ----------------------------
# GRAPH TRUNCATION
(maxy, miny, maxx, minx) = kznsal.total_bounds 
bbox = (maxy, miny, maxx, minx)

kzndrive = ox.truncate.truncate_graph_bbox(kzndrive, bbox)

# %%
# ----------------------------
# NODE ASSIGNMENT
# ----------------------------
kznsal["node"] = ox.nearest_nodes(
    kzndrive,
    kznsal.geometry.x,
    kznsal.geometry.y
)


pharm_gdf["node"] = ox.nearest_nodes(
    kzndrive,
    pharm_gdf.geometry.x,
    pharm_gdf.geometry.y
)

# %%
# ----------------------------
# STEP 1: Rj (SUPPLY SIDE)
# ----------------------------
Rj_list = []

for idx, pharm in tqdm(pharm_gdf.iterrows(), total=len(pharm_gdf)):

    lengths = nx.single_source_dijkstra_path_length(
        kzndrive,
        pharm["node"],
        cutoff=8000,
        weight="length"
    )

    reachable_nodes = set(lengths.keys())

    nearby_pop = kznsal[kznsal["node"].isin(reachable_nodes)]

    total_pop = nearby_pop["sal2023_est"].sum()

    Rj = 5000 / total_pop if total_pop > 0 else 0 
    Rj_list.append(Rj)

pharm_gdf = pharm_gdf.reset_index(drop=True)
pharm_gdf["Rj"] = Rj_list
# ----------------------------
# STEP 2: Ai (DEMAND SIDE)
# ----------------------------
Ai_list = []

for idx, pop in tqdm(kznsal.iterrows(), total=len(kznsal)):

    lengths = nx.single_source_dijkstra_path_length(
        kzndrive,
        pop["node"],
        cutoff=8000, 
        weight="length"
    )

    reachable_nodes = set(lengths.keys())

    nearby_pharm = pharm_gdf[pharm_gdf["node"].isin(reachable_nodes)]

    Ai = nearby_pharm["Rj"].sum()

    Ai_list.append(Ai)

kznsal["Ai_drive"] = Ai_list
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1757/1757 [00:25<00:00, 68.58it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 15539/15539 [02:24<00:00, 107.35it/s]

# %%
kznsal["Ai_drive"].describe()
# Out:
# count    15539.000000
# mean         0.955348
# std          2.036582
# min          0.000000
# 25%          0.000000
# 50%          0.225252
# 75%          1.357495
# max        168.618728
# Name: Ai_drive, dtype: float64

# %%
nearby_pop["sal2023_est"].describe()
# Out:
# count     272.000000
# mean      655.514987
# std       474.813346
# min         0.000000
# 25%       367.932790
# 50%       631.964104
# 75%       810.846952
# max      2696.998560
# Name: sal2023_est, dtype: float64

# %%
#----------------
# Gauteng Walk Analysis 
# Walk Catchment: 2km (2000m)(1.25mi)
# Pharmacy Population Demand Catchment: 8km (8000m) (5mi)

# Pharmacy Supply: 10000/catchment pop (we must assume equal supply accross pharamcies due to limited data)
#Here we assume double pharmacy supply due to existing literature that Gauteng has the most medical resources within SA and a stronger demand 

# Pharmacy Catchment Population Distribution
# mean      383.150275
# std       266.742063
# min         0.000000
# 25%       231.700370
# 50%       324.216323
# 75%       456.268802
# max      2282.328768

# %%
gauwalk=ox.load_graphml('../../networks/network_gauteng_walk.graphml')
gauwalk = ox.project_graph(gauwalk)
gauwalk.graph["crs"]
# Out:
# <Projected CRS: EPSG:32735>
# Name: WGS 84 / UTM zone 35S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 24°E and 30°E, southern hemisphere between 80°S and equator, onshore and offshore. Botswana. Burundi. Democratic Republic of the Congo (Zaire). Rwanda. South Africa. Tanzania. Uganda. Zambia. Zimbabwe.
# - bounds: (24.0, -80.0, 30.0, 0.0)
# Coordinate Operation:
# - name: UTM zone 35S
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gausal = gausal.to_crs(gauwalk.graph["crs"])
gaupharm = gaupharm.to_crs(gauwalk.graph["crs"])

# %%
# ----------------------------
# GRAPH TRUNCATION
(maxy, miny, maxx, minx) = gausal.total_bounds 
bbox = (maxy, miny, maxx, minx)

gauwalk = ox.truncate.truncate_graph_bbox(gauwalk, bbox)

# %%
# NODE ASSIGNMENT
# ----------------------------


gausal["node"] = ox.nearest_nodes(
    gauwalk,
    gausal.geometry.x,
    gausal.geometry.y
)

pharm_gdf = gaupharm.copy()
pharm_gdf = pharm_gdf[
    pharm_gdf.geometry.x.notna() &
    pharm_gdf.geometry.y.notna()
]

pharm_gdf["node"] = ox.nearest_nodes(
    gauwalk,
    pharm_gdf.geometry.x,
    pharm_gdf.geometry.y
)

# %%
# ----------------------------
# STEP 1: Rj (SUPPLY SIDE)
# ----------------------------
Rj_list = []

for idx, pharm in tqdm(pharm_gdf.iterrows(), total=len(pharm_gdf)):

    lengths = nx.single_source_dijkstra_path_length(
        gauwalk,
        pharm["node"],
        cutoff=8000, #equal m per pharm
        weight="length"
    )

    reachable_nodes = set(lengths.keys())

    nearby_pop = gausal[gausal["node"].isin(reachable_nodes)]

    total_pop = nearby_pop["sal2023_est"].sum()

    Rj = 10000 / total_pop if total_pop > 0 else 0  

    Rj_list.append(Rj)

pharm_gdf = pharm_gdf.reset_index(drop=True)
pharm_gdf["Rj"] = Rj_list
# ----------------------------
# STEP 2: Ai (DEMAND SIDE)
# ----------------------------
Ai_list = []

for idx, pop in tqdm(gausal.iterrows(), total=len(gausal)):

    lengths = nx.single_source_dijkstra_path_length(
        gauwalk,
        pop["node"],
        cutoff=2000, #since this is the walking graph, doing 1 mile for every sal (1609m)   
        weight="length"
    )

    reachable_nodes = set(lengths.keys())

    nearby_pharm = pharm_gdf[pharm_gdf["node"].isin(reachable_nodes)]

    Ai = nearby_pharm["Rj"].sum()

    Ai_list.append(Ai)

gausal["Ai_walk"] = Ai_list
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2991/2991 [02:38<00:00, 18.91it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 18528/18528 [01:09<00:00, 267.02it/s]

# %%
gausal["Ai_walk"].describe()
# Out:
# count    18528.000000
# mean         0.285302
# std          3.465464
# min          0.000000
# 25%          0.000000
# 50%          0.045937
# 75%          0.285199
# max        453.933226
# Name: Ai_walk, dtype: float64

# %%
nearby_pop["sal2023_est"].describe()
# Out:
# count     503.000000
# mean      382.541591
# std       266.713582
# min         0.000000
# 25%       231.973307
# 50%       323.711059
# 75%       455.924107
# max      2282.328768
# Name: sal2023_est, dtype: float64

# %%
#--------------------
# Gauteng Road Analysis 
# Drive Catchment: 8km (8000m)(5mi)
# Pharmacy Population Demand Catchment: 8km (8000m) (5mi)

# Pharmacy Supply: 10000/catchment pop (we must assume equal supply accross pharamcies due to limited data)
#Here we assume double pharmacy supply due to existing literature that Gauteng has the most medical resources within SA and a larger demand 

# Pharmacy Catchment Population Distribution
# mean      380.677203
# std       268.025377
# min         0.000000
# 25%       229.249150
# 50%       322.719567
# 75%       456.931665
# max      2282.328768

# %%
gaudrive=ox.load_graphml('../../networks/network_gauteng_drive.graphml')
gaudrive = ox.project_graph(gaudrive)
gaudrive.graph["crs"]
# Out:
# <Projected CRS: EPSG:32735>
# Name: WGS 84 / UTM zone 35S
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 24°E and 30°E, southern hemisphere between 80°S and equator, onshore and offshore. Botswana. Burundi. Democratic Republic of the Congo (Zaire). Rwanda. South Africa. Tanzania. Uganda. Zambia. Zimbabwe.
# - bounds: (24.0, -80.0, 30.0, 0.0)
# Coordinate Operation:
# - name: UTM zone 35S
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gausal = gausal.to_crs(gaudrive.graph["crs"])
gaupharm = gaupharm.to_crs(gaudrive.graph["crs"])

# %%
# ----------------------------
# GRAPH TRUNCATION
(maxy, miny, maxx, minx) = gausal.total_bounds 
bbox = (maxy, miny, maxx, minx)

gaudrive = ox.truncate.truncate_graph_bbox(gaudrive, bbox)

# %%
# ----------------------------
# NODE ASSIGNMENT
# ----------------------------
gausal["node"] = ox.nearest_nodes(
    gaudrive,
    gausal.geometry.x,
    gausal.geometry.y
)

pharm_gdf["node"] = ox.nearest_nodes(
    gaudrive,
    pharm_gdf.geometry.x,
    pharm_gdf.geometry.y
)

# %%
# ----------------------------
# STEP 1: Rj (SUPPLY SIDE)
# ----------------------------
Rj_list = []

for idx, pharm in tqdm(pharm_gdf.iterrows(), total=len(pharm_gdf)):

    lengths = nx.single_source_dijkstra_path_length(
        gaudrive,
        pharm["node"],
        cutoff=8000,
        weight="length"
    )

    reachable_nodes = set(lengths.keys())

    nearby_pop = gausal[gausal["node"].isin(reachable_nodes)]

    total_pop = nearby_pop["sal2023_est"].sum()

    Rj = 10000 / total_pop if total_pop > 0 else 0  

    Rj_list.append(Rj)

pharm_gdf = pharm_gdf.reset_index(drop=True)
pharm_gdf["Rj"] = Rj_list
# ----------------------------
# STEP 2: Ai (DEMAND SIDE)
# ----------------------------
Ai_list = []

for idx, pop in tqdm(gausal.iterrows(), total=len(gausal)):

    lengths = nx.single_source_dijkstra_path_length(
        gaudrive,
        pop["node"],
        cutoff=8000, 
        weight="length"
    )

    reachable_nodes = set(lengths.keys())

    nearby_pharm = pharm_gdf[pharm_gdf["node"].isin(reachable_nodes)]

    Ai = nearby_pharm["Rj"].sum()

    Ai_list.append(Ai)

gausal["Ai_drive"] = Ai_list
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2991/2991 [02:05<00:00, 23.77it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 18528/18528 [07:19<00:00, 42.17it/s]

# %%
gausal["Ai_drive"].describe()
# Out:
# count    18528.000000
# mean        12.604165
# std         36.340593
# min          0.000000
# 25%          0.521955
# 50%          1.714455
# 75%          5.943741
# max        495.199883
# Name: Ai_drive, dtype: float64

# %%
nearby_pop["sal2023_est"].describe()
# Out:
# count     501.000000
# mean      380.677203
# std       268.025377
# min         0.000000
# 25%       229.249150
# 50%       322.719567
# 75%       456.931665
# max      2282.328768
# Name: sal2023_est, dtype: float64

# %%
kznsal = kznsal.to_crs("EPSG:32735")  # UTM zone 35S
gausal = gausal.to_crs("EPSG:32735")


allaccess = pd.concat([kznsal, gausal], ignore_index=True)
allaccess = allaccess.drop(columns='geometry')

allaccess = salpoly.merge(allaccess, on='EA_CODE', how='left')
cols = ['Ai_walk', 'Ai_drive' ]

allaccess[cols] = allaccess[cols].fillna(0)
# Out:
# C:\Users\kalmanj\AppData\Local\Temp\ipykernel_13792\1549509868.py:8: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   allaccess = salpoly.merge(allaccess, on='EA_CODE', how='left')

# %%
allaccess['geometry'] = allaccess.geometry.to_wkt()
allaccess.to_csv("../../new_allaccess.csv", index=False)
# Out:
# C:\Users\kalmanj\AppData\Local\Temp\ipykernel_13792\1902690010.py:1: UserWarning: Geometry column does not contain geometry.
#   allaccess['geometry'] = allaccess.geometry.to_wkt()

# %%
### MAPS

# %%
pharm_with_sal = pharm_with_sal.to_crs(allaccess.crs)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

cols = ['Ai_walk', 'Ai_drive']

bin_edges = [0, 0.25, 0.5, 0.75, 1]

fig, axes = plt.subplots(1, 2, figsize=(14,8))

cmap = mpl.cm.RdYlGn

for i, col in enumerate(cols):

    allaccess.plot(
        column=col,
        cmap=cmap,
        scheme='UserDefined',
        classification_kwds={'bins': bin_edges},
        legend=False,
        ax=axes[i],
        edgecolor="none"
    )

    axes[i].set_title(f"{col.capitalize()} Accessibility")
    axes[i].axis('off')

# shared colorbar
norm = mpl.colors.BoundaryNorm(bin_edges, ncolors=cmap.N)
sm = mpl.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

cbar = fig.colorbar(sm, ax=axes, fraction=0.03, pad=0.02)
cbar.set_label("Accessibility Score")

plt.suptitle("Walking vs Driving Accessibility")

plt.savefig("images/walk_vs_drive.png", dpi=150, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

bin_edges = [0, 0.25, 0.5, 0.75, 1]

fig, ax = plt.subplots(figsize=(8,8))

cmap = mpl.cm.RdYlGn
norm = mpl.colors.BoundaryNorm(bin_edges, ncolors=cmap.N)

# polygon layer (walking)
allaccess.plot(
    column='Ai_walk',
    cmap=cmap,
    norm=norm,
    edgecolor="none",
    ax=ax
)

# pharmacy points
pharm_with_sal.plot(
    ax=ax,
    color='blue',
    markersize=6,
    alpha=0.8
)

# Johannesburg zoom
ax.set_xlim(27.7, 28.3)
ax.set_ylim(-26.4, -25.8)

# colorbar
sm = mpl.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

cbar = fig.colorbar(sm, ax=ax, fraction=0.035, pad=0.02)
cbar.set_label("Walking Accessibility")

ax.set_title("Walking Accessibility (Johannesburg)")
ax.axis('off')
plt.savefig("images/joburg_walk.png", dpi=150, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

fig, ax = plt.subplots(figsize=(8,8))

bin_edges = [0, 0.25, 0.5, 0.75, 1]

cmap = mpl.cm.RdYlGn
norm = mpl.colors.BoundaryNorm(bin_edges, ncolors=cmap.N)

# polygons
allaccess.plot(
    column='Ai_walk',
    cmap=cmap,
    norm=norm,   
    edgecolor="none",
    ax=ax
)

# make sure CRS matches
pharm_with_sal = pharm_with_sal.to_crs(allaccess.crs)

# pharmacies
pharm_with_sal.plot(
    ax=ax,
    color='blue',
    markersize=6,
    alpha=0.8
)

# Durban zoom
ax.set_xlim(30.85, 31.25)
ax.set_ylim(-30.05, -29.65)

# colorbar
sm = mpl.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

cbar = fig.colorbar(sm, ax=ax, fraction=0.035, pad=0.02)
cbar.set_label("Accessibility Score")

ax.set_title("Durban Walking Accessibility")
ax.axis('off')
plt.savefig("images/durban_walk.png", dpi=150, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

bin_edges = [0, 0.25, 0.5, 0.75,1]
cmap = mpl.cm.RdYlGn

norm = mpl.colors.BoundaryNorm(bin_edges, cmap.N)

fig, axes = plt.subplots(1, 2, figsize=(14, 8))

cities = {
    "Johannesburg": (27.7, 28.3, -26.4, -25.8),
    "Durban": (30.85, 31.25, -30.05, -29.65)
}

for i, (name, (xmin, xmax, ymin, ymax)) in enumerate(cities.items()):

    gdf = allaccess.cx[xmin:xmax, ymin:ymax]

    gdf.plot(
        column='Ai_walk',
        cmap=cmap,
        norm=norm,         
        ax=axes[i],
        edgecolor='none'
    )

    # pharm_with_sal.cx[xmin:xmax, ymin:ymax].plot(
    #     ax=axes[i],
    #     color='#3B0C87',
    #     markersize= 1,
    #     zorder=10
    # )

    axes[i].set_title(name)
    axes[i].axis('off')

sm = mpl.cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])

cbar = fig.colorbar(sm, ax=axes, fraction=0.03, pad=0.02)
cbar.set_label("Accessibility Score")

plt.suptitle("Walking Accessibility: Johannesburg vs Durban")
plt.savefig("joburgandDurban_walking.png", dpi=150, bbox_inches='tight')

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

bin_edges = [0, 0.25, 0.5, 0.75,1]
cmap = mpl.cm.RdYlGn

norm = mpl.colors.BoundaryNorm(bin_edges, cmap.N)

fig, axes = plt.subplots(1, 2, figsize=(14, 8))

cities = {
    "Johannesburg": (27.7, 28.3, -26.4, -25.8),
    "Durban": (30.85, 31.25, -30.05, -29.65)
}

for i, (name, (xmin, xmax, ymin, ymax)) in enumerate(cities.items()):

    gdf = allaccess.cx[xmin:xmax, ymin:ymax]

    gdf.plot(
        column='Ai_drive',
        cmap=cmap,
        norm=norm,         
        ax=axes[i],
        edgecolor='none'
    )

    # pharm_with_sal.cx[xmin:xmax, ymin:ymax].plot(
    #     ax=axes[i],
    #     color='#3B0C87',
    #     markersize= 1,
    #     zorder=10
    # )

    axes[i].set_title(name)
    axes[i].axis('off')

sm = mpl.cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])

cbar = fig.colorbar(sm, ax=axes, fraction=0.03, pad=0.02)
cbar.set_label("Accessibility Score")

plt.suptitle("Driving Accessibility: Johannesburg vs Durban")
plt.savefig("joburgandDurban_driving.png", dpi=150, bbox_inches='tight')

plt.show()

# %%
highlight_codes = [
59914140,
59915043,
59914126,
59915036,
59914137,
59915050,
59914147,
59915054,
59915057,
59914138,
]  

fig, ax = plt.subplots(figsize=(8,8))

# filter to one province
gdf_prov = allaccess[allaccess['PR_NAME_x'] == 'KwaZulu-Natal']

# base layer (all polygons)
gdf_prov.plot(
    ax=ax,
    color='lightgrey',
    edgecolor='none'
)

# highlighted polygons
gdf_prov[gdf_prov['EA_CODE'].isin(highlight_codes)].plot(
    ax=ax,
    color='red',
    edgecolor='black',
    linewidth=0.5
)

ax.set_title("Highlighted EA Codes - KZN")
ax.axis('off')

plt.show()

# %%
highlight_codes = [
59914140,
59915043,
59914126,
59915036,
59914137,
59915050,
59914147,
59915054,
59915057,
59914138,
]  

fig, ax = plt.subplots(figsize=(8,8))

gdf_prov = allaccess[allaccess['PR_NAME_x'] == 'KwaZulu-Natal']

subset = gdf_prov[gdf_prov['EA_CODE'].isin(highlight_codes)]

# base
gdf_prov.plot(ax=ax, color='lightgrey', edgecolor='white')

# highlight
subset.plot(ax=ax, color='red', edgecolor='black', linewidth=0.5)
#pharmacy points
pharm_with_sal.plot(
    ax=ax,
    color='blue',
    markersize=6,
    alpha=0.8
)

# after polygons + pharmacies
ax.scatter(31.0218, -29.8587, color='orange', s=25, zorder=20)
ax.text(31.0218+0.02, -29.8587, "Durban", fontsize=10, ha='left')
# 🔥 AUTO ZOOM
minx, miny, maxx, maxy = subset.total_bounds

# optional padding so it's not tight
pad_x = (maxx - minx) * 2
pad_y = (maxy - miny) * 3

ax.set_xlim(minx - pad_x, maxx + pad_x)
ax.set_ylim(miny - pad_y, maxy + pad_y)

ax.set_title("Bottom 10 Driving Accessibility Score - KZN")
ax.axis('off')
plt.savefig("images/bottomdrive.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
highlight_codes = [

79814126,
79814112,
79814128,
79814136,
79815745,
79814137,
79815736,
79814114,
79814127,

]  

fig, ax = plt.subplots(figsize=(8,8))

gdf_prov = allaccess[allaccess['PR_NAME_x'] == 'Gauteng']

subset = gdf_prov[gdf_prov['EA_CODE'].isin(highlight_codes)]

# base
gdf_prov.plot(ax=ax, color='lightgrey', edgecolor='white')

# highlight
subset.plot(ax=ax, color='lightgreen', edgecolor='black', linewidth=0.5)
#pharmacy points
pharm_with_sal.plot(
    ax=ax,
    color='blue',
    markersize=6,
    alpha=0.8
)

# after polygons + pharmacies
ax.scatter(28.0473, -26.2041, color='orange', s=60, zorder=6)
ax.text(28.0473+0.01, -26.2041, "Johannesburg", fontsize=10)
minx, miny, maxx, maxy = subset.total_bounds


# optional padding so it's not tight
pad_x = (maxx - minx) * 3.5
pad_y = (maxy - miny) * 3.5

ax.set_xlim(minx - pad_x, maxx + pad_x)
ax.set_ylim(miny - pad_y, maxy + pad_y)

ax.set_title("Top 9 Driving Accessibility Score ")
ax.axis('off')
plt.savefig("images/topdrive.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
highlight_codes = [


59914267,
59914272,
59913977,
59914251,
59914249,
59913982,
59914927,
59914184,
59914187,
59914197,


]  

fig, ax = plt.subplots(figsize=(8,8))

gdf_prov = allaccess[allaccess['PR_NAME_x'] == 'KwaZulu-Natal']

subset = gdf_prov[gdf_prov['EA_CODE'].isin(highlight_codes)]

# base
gdf_prov.plot(ax=ax, color='lightgrey', edgecolor='white')

# highlight
subset.plot(ax=ax, color='red', edgecolor='black', linewidth=0.5)
#pharmacy points
pharm_with_sal.plot(
    ax=ax,
    color='blue',
    markersize=6,
    alpha=0.8
)

# after polygons + pharmacies
ax.scatter(31.0218, -29.8587, color='orange', s=25, zorder=20)
ax.text(31.0218+0.02, -29.8587, "Durban", fontsize=10, ha='left')
minx, miny, maxx, maxy = subset.total_bounds


# optional padding so it's not tight
pad_x = (maxx - minx) * 2
pad_y = (maxy - miny) * 2

ax.set_xlim(minx - pad_x, maxx + pad_x)
ax.set_ylim(miny - pad_y, maxy + pad_y)

ax.set_title("Bottom 10 Walking Accessibility Score ")
ax.axis('off')
plt.savefig("images/topdrive.png", dpi=300, bbox_inches='tight')

plt.show()

# %%
highlight_codes = [

79913191,
76010001,
76110002,
79911565,
76110001,

76310678,
76310681,
76310680,


]  

fig, ax = plt.subplots(figsize=(8,8))

gdf_prov = allaccess

subset = gdf_prov[gdf_prov['EA_CODE'].isin(highlight_codes)]

# base
gdf_prov.plot(ax=ax, color='lightgrey', edgecolor='white')

# highlight
subset.plot(ax=ax, color='red', edgecolor='red', linewidth=0.5)
#pharmacy points
pharm_with_sal.plot(
    ax=ax,
    color='blue',
    markersize=2,
    alpha=0.8
)



minx, miny, maxx, maxy = subset.total_bounds


# optional padding so it's not tight
pad_x = (maxx - minx)*0.75
pad_y = (maxy - miny)*0.75
ax.set_xlim(minx - pad_x, maxx + pad_x)
ax.set_ylim(miny - pad_y, maxy + pad_y)

ax.set_title("Top 10 Walking Accessibility Score ")
ax.axis('off')
#plt.savefig("images/bottomwalk.png", dpi=300, bbox_inches='tight')

plt.show()
