# %%
import geopandas as gpd
import pandas as pd
import numpy as np
from shapely.geometry import Point
from scipy.ndimage import gaussian_filter
import matplotlib.pyplot as plt
from shapely.geometry import box

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Tess\Desktop\UPenn\UPenn_SS26\MUSA_8010-001_Practicum\south-africa-healthcare

# %%
sal = gpd.read_file("data/2011_census/2011_census/ea_sal_kzn_gp.shp")

wards = gpd.read_file("data/2023_census/2023_census/SA_Wards2020.shp")

wards_with_pop = gpd.read_file("data/2023_census/PP_Population Group_27-10-2025.csv")

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)

pd.set_option('display.max_columns', 100)

# %%
sal.columns
# Out:
# Index(['OBJECTID', 'EA_CODE', 'SP_CODE', 'SP_NAME', 'MP_CODE', 'MP_NAME',
#        'MN_MDB_C', 'MN_CODE', 'MN_NAME', 'MN_TYPE', 'DC_MDB_C', 'DC_MN_C',
#        'DC_NAME', 'PR_MDB_C', 'PR_CODE', 'PR_NAME', 'EA_GTYPE', 'ALBERS_ARE',
#        'MD_CODE', 'MD_NAME', 'Shape_Leng', 'Shape_Area', 'SAL_CODE', 'EA_TYPE',
#        '4_class', 'EA_area_km', 'num_houses', '4_class_2', 'num_build',
#        'EA_CODE_1', 'old_EA_TYP', 'smallplace', 'url', 'Black Afri', 'White',
#        'Coloured', 'Indian or', 'Other', 'population', '0_4', '5_9', '10_14',
#        '15_19', '20_24', '25_29', '30_34', '35_39', '40_44', '45_49', '50_54',
#        '55_59', '60_64', '65_69', '70_74', '75_79', '80_84', '85+',
#        'geometry'],
#       dtype='str')

# %%
wards.columns
# Out:
# Index(['Province', 'Municipali', 'CAT_B', 'WardNo', 'District', 'DistrictCo',
#        'Date', 'WardID', 'WardLabel', 'geometry'],
#       dtype='str')

# %%
wards_with_pop.columns
# Out:
# Index(['Ward_Code', 'Black African', 'Coloured', 'Indian/Asian', 'White',
#        'Other', 'Total'],
#       dtype='str')

# %%
wards_with_pop = wards_with_pop.rename(columns = {"Ward_Code" : "WardID"})

# %%
wards = wards.merge(
    wards_with_pop[['WardID', 'Total',]],
    on='WardID',
    how='left'
)

# %%
wards = wards[wards['Province'].isin(['Gauteng', 'KwaZulu-Natal'])].copy()

# %%
sal['population'].isna().sum()
# Out:
# np.int64(2084)

# %%
wards
# Out:
#            Province                         Municipali   CAT_B  WardNo  \
# 1994  KwaZulu-Natal       Abaqulusi Local Municipality  KZN263       1
# 1995  KwaZulu-Natal       Abaqulusi Local Municipality  KZN263       2
# 1996  KwaZulu-Natal       Abaqulusi Local Municipality  KZN263       3
# 1997  KwaZulu-Natal       Abaqulusi Local Municipality  KZN263       4
# 1998  KwaZulu-Natal       Abaqulusi Local Municipality  KZN263       5
# ...             ...                                ...     ...     ...
# 3419        Gauteng  Rand West City Local Municipality   GT485      31
# 3420        Gauteng  Rand West City Local Municipality   GT485      32
# 3421        Gauteng  Rand West City Local Municipality   GT485      33
# 3422        Gauteng  Rand West City Local Municipality   GT485      34
# 3423        Gauteng  Rand West City Local Municipality   GT485      35
#
#        District DistrictCo       Date    WardID WardLabel  \
# 1994   Zululand       DC26 2020-11-24  52603001  KZN263_1
# 1995   Zululand       DC26 2020-11-24  52603002  KZN263_2
# 1996   Zululand       DC26 2020-11-24  52603003  KZN263_3
# 1997   Zululand       DC26 2020-11-24  52603004  KZN263_4
# 1998   Zululand       DC26 2020-11-24  52603005  KZN263_5
# ...         ...        ...        ...       ...       ...
# 3419  West Rand       DC48 2020-11-26  74805031  GT485_31
# 3420  West Rand       DC48 2020-11-26  74805032  GT485_32
# 3421  West Rand       DC48 2020-11-26  74805033  GT485_33
# 3422  West Rand       DC48 2020-11-26  74805034  GT485_34
# 3423  West Rand       DC48 2020-11-26  74805035  GT485_35
#
#                                                geometry  Total
# 1994  POLYGON ((31.17994 -27.4445, 31.18019 -27.4445...   9172
# 1995  POLYGON ((31.39678 -27.57043, 31.4013 -27.5732...   7556
# 1996  POLYGON ((31.29273 -27.71005, 31.30908 -27.716...  10620
# 1997  POLYGON ((31.21784 -27.83956, 31.2495 -27.8510...   9852
# 1998  POLYGON ((31.05784 -27.72982, 31.04077 -27.760...  10441
# ...                                                 ...    ...
# 3419  POLYGON ((27.70118 -26.279, 27.69996 -26.2794,...   6718
# 3420  POLYGON ((27.74465 -26.27949, 27.73847 -26.282...  10980
# 3421  POLYGON ((27.72198 -26.23594, 27.72473 -26.238...   8474
# 3422  POLYGON ((27.69489 -26.28297, 27.69489 -26.283...   8158
# 3423  POLYGON ((27.7062 -26.28687, 27.70623 -26.2878...   8965
#
# [1430 rows x 11 columns]

# %%
sal
# Out:
#        OBJECTID    EA_CODE     SP_CODE                  SP_NAME  MP_CODE  \
# 0         28217 50,310,272 503,001,001         KwaMaqikizane SP  503,001
# 1         28623 50,310,271 503,001,001         KwaMaqikizane SP  503,001
# 2         28431 50,310,262 503,002,001             Mthwalume SP  503,002
# 3         28241 50,310,266 503,002,001             Mthwalume SP  503,002
# 4         28287 50,310,265 503,003,001             Ngomakazi SP  503,003
# ...         ...        ...         ...                      ...      ...
# 39172    103449 59,912,265 599,116,038              Mariannhill  599,116
# 39173    103472 59,914,036 599,099,002                  Assagay  599,099
# 39174    103475 59,915,062 599,051,016                 Eastbury  599,051
# 39175    103558 59,911,731 599,116,035  Mariann Industrial Park  599,116
# 39176    103566 59,912,077 599,116,015           Mountain Ridge  599,116
#
#                  MP_NAME MN_MDB_C  MN_CODE    MN_NAME MN_TYPE DC_MDB_C  \
# 0          KwaMaqikizane   KZN213      503    Umzumbe    CATB     DC21
# 1          KwaMaqikizane   KZN213      503    Umzumbe    CATB     DC21
# 2              Mthwalume   KZN213      503    Umzumbe    CATB     DC21
# 3              Mthwalume   KZN213      503    Umzumbe    CATB     DC21
# 4              Ngomakazi   KZN213      503    Umzumbe    CATB     DC21
# ...                  ...      ...      ...        ...     ...      ...
# 39172           Pinetown      ETH      599  Ethekwini   METRO      ETH
# 39173  Outer West Durban      ETH      599  Ethekwini   METRO      ETH
# 39174            Phoenix      ETH      599  Ethekwini   METRO      ETH
# 39175           Pinetown      ETH      599  Ethekwini   METRO      ETH
# 39176           Pinetown      ETH      599  Ethekwini   METRO      ETH
#
#        DC_MN_C                 DC_NAME PR_MDB_C  PR_CODE        PR_NAME  \
# 0          521                     Ugu      KZN        5  KwaZulu-Natal
# 1          521                     Ugu      KZN        5  KwaZulu-Natal
# 2          521                     Ugu      KZN        5  KwaZulu-Natal
# 3          521                     Ugu      KZN        5  KwaZulu-Natal
# 4          521                     Ugu      KZN        5  KwaZulu-Natal
# ...        ...                     ...      ...      ...            ...
# 39172      599  eThekwini Metropolitan      KZN        5  KwaZulu-Natal
# 39173      599  eThekwini Metropolitan      KZN        5  KwaZulu-Natal
# 39174      599  eThekwini Metropolitan      KZN        5  KwaZulu-Natal
# 39175      599  eThekwini Metropolitan      KZN        5  KwaZulu-Natal
# 39176      599  eThekwini Metropolitan      KZN        5  KwaZulu-Natal
#
#           EA_GTYPE  ALBERS_ARE  MD_CODE MD_NAME  Shape_Leng  Shape_Area  \
# 0      Traditional           6        0    None           0           0
# 1      Traditional           4        0    None           0           0
# 2      Traditional           2        0    None           0           0
# 3      Traditional           2        0    None           0           0
# 4      Traditional           4        0    None           0           0
# ...            ...         ...      ...     ...         ...         ...
# 39172        Urban           1        0    None           0           0
# 39173        Urban           4        0    None           0           0
# 39174        Urban           0        0    None           0           0
# 39175        Urban           1        0    None           0           0
# 39176        Urban           0        0    None           0           0
#
#        SAL_CODE                  EA_TYPE      4_class  EA_area_km  num_houses  \
# 0       5030083  Traditional residential  Non_Wealthy       1,507         131
# 1       5030157  Traditional residential  Non_Wealthy       1,275         167
# 2       5030040  Traditional residential  Non_Wealthy       1,121         135
# 3       5030172  Traditional residential  Non_Wealthy       1,161         154
# 4       5030022  Traditional residential  Non_Wealthy         932          92
# ...         ...                      ...          ...         ...         ...
# 39172   5990011                 Vacant_*          NaN           0           0
# 39173   5990895            Smallholdings      Wealthy       1,922         180
# 39174   5990753     Formal residential_*          NaN           0           0
# 39175   5990111     Informal residential  Non_Wealthy         148          26
# 39176         0                 Vacant_*          NaN           0           0
#
#          4_class_2  num_build  EA_CODE_1               old_EA_TYP smallplace  \
# 0      Non_Wealthy        131 50,310,272  Traditional residential    5030083
# 1      Non_Wealthy        167 50,310,271  Traditional residential    5030157
# 2      Non_Wealthy        135 50,310,262  Traditional residential    5030040
# 3      Non_Wealthy        153 50,310,266  Traditional residential    5030172
# 4      Non_Wealthy         92 50,310,265  Traditional residential    5030022
# ...            ...        ...        ...                      ...        ...
# 39172          NaN        NaN        NaN                      NaN        NaN
# 39173          NaN        NaN        NaN                      NaN        NaN
# 39174          NaN        NaN        NaN                      NaN        NaN
# 39175          NaN        NaN        NaN                      NaN        NaN
# 39176          NaN        NaN        NaN                      NaN        NaN
#
#                                                     url Black Afri White  \
# 0      https://census2011.adrianfrith.com/place/5030083        558     0
# 1      https://census2011.adrianfrith.com/place/5030157        713     0
# 2      https://census2011.adrianfrith.com/place/5030040        443     0
# 3      https://census2011.adrianfrith.com/place/5030172        740     0
# 4      https://census2011.adrianfrith.com/place/5030022        339     0
# ...                                                 ...        ...   ...
# 39172                                               NaN        NaN   NaN
# 39173                                               NaN        NaN   NaN
# 39174                                               NaN        NaN   NaN
# 39175                                               NaN        NaN   NaN
# 39176                                               NaN        NaN   NaN
#
#       Coloured Indian or Other population  0_4  5_9 10_14 15_19 20_24 25_29  \
# 0            0         1     0        559   79   84    72    79    42    26
# 1            0         0     0        713  101  104   104    84    51    41
# 2            0         0     0        443   71   60    48    49    40    23
# 3            1         1     1        743  112   97    97    91    64    50
# 4            0         0     0        339   55   39    40    47    19    17
# ...        ...       ...   ...        ...  ...  ...   ...   ...   ...   ...
# 39172      NaN       NaN   NaN        NaN  NaN  NaN   NaN   NaN   NaN   NaN
# 39173      NaN       NaN   NaN        NaN  NaN  NaN   NaN   NaN   NaN   NaN
# 39174      NaN       NaN   NaN        NaN  NaN  NaN   NaN   NaN   NaN   NaN
# 39175      NaN       NaN   NaN        NaN  NaN  NaN   NaN   NaN   NaN   NaN
# 39176      NaN       NaN   NaN        NaN  NaN  NaN   NaN   NaN   NaN   NaN
#
#       30_34 35_39 40_44 45_49 50_54 55_59 60_64 65_69 70_74 75_79 80_84  85+  \
# 0        23    22    20    27    23    14    13    10     9     4     6    2
# 1        19    26    28    30    25    21    33    19     8     7     3    3
# 2        22    26    12    17    17    25    10     4     5     4     6    3
# 3        27    28    30    31    21    28    22    15     7     8    10    4
# 4        18     9    12    19    14     8    11    12     1     4     6    1
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 39172   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 39173   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 39174   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 39175   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
# 39176   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  NaN
#
#                                                 geometry
# 0      POLYGON ((30.35725 -30.34275, 30.35653 -30.343...
# 1      POLYGON ((30.32346 -30.35142, 30.32346 -30.351...
# 2      POLYGON ((30.37881 -30.35548, 30.37855 -30.356...
# 3      POLYGON ((30.3679 -30.34296, 30.36784 -30.3430...
# 4      POLYGON ((30.36924 -30.36119, 30.36892 -30.361...
# ...                                                  ...
# 39172  POLYGON ((30.83722 -29.84231, 30.83673 -29.842...
# 39173  POLYGON ((30.73516 -29.7538, 30.73538 -29.7538...
# 39174  POLYGON ((31.02621 -29.70455, 31.02627 -29.704...
# 39175  POLYGON ((30.87284 -29.86353, 30.87285 -29.863...
# 39176  POLYGON ((30.89344 -29.81163, 30.89342 -29.810...
#
# [39177 rows x 58 columns]

# %%
sal_with_ward = gpd.read_file("data/sal_w_ward_new/sal_w_ward_new.shp")

# %%
pd.set_option('display.float_format', '{:,.2f}'.format)

# %%
sal_with_ward=sal_with_ward.rename(columns={'census_war': 'WardID'})

# %%
sal_with_ward = sal_with_ward.merge(
    wards[['WardID', 'Total']],
    on='WardID',
    how='left'
)

# %%
sal_wards= sal_with_ward[['WardID', 'EA_CODE', 'sal2011_po', "Total", 'EA_GTYPE', 'EA_TYPE', 'F4_class', 'num_houses', 
                         'Black_Afri', 'White', 'Coloured', 'Indian_or', 'Other',    ]]

# %%
sal_wards=sal_wards.rename(columns={'sal2011_po': 'sal2011_pop',
                            'Total':'ward2023_pop',
                                'F4_class': 'econ_status',
                                'num_houses': 'houses2011'})

# %%
sal_wards['EA_TYPE'] = sal_wards['EA_TYPE'].str.replace(r'_\*$', '', regex=True)
sal_wards['EA_TYPE'] = sal_wards['EA_TYPE'].str.replace(
    'Smallholdings', 'Small holdings'
)

# %%
sal_wards.loc[sal_wards['sal2011_pop'] == 0, 'sal2011_pop'] = sal_wards['houses2011']*3


sal_wards['area_km2'] = sal_with_ward.geometry.area / 1e6

sal_wards['sal_dense'] = (
    sal_wards['sal2011_pop'].astype(float) /
    sal_wards['area_km2'].astype(float)
)
sal_wards['log_density'] = np.log1p(sal_wards['sal_dense'])

# %%
sal_wards
# Out:
#          WardID       EA_CODE  sal2011_pop ward2023_pop     EA_GTYPE  \
# 0      52103007 50,310,272.00       559.00         5887  Traditional
# 1      52103007 50,310,271.00       713.00         5887  Traditional
# 2      52103007 50,310,262.00       443.00         5887  Traditional
# 3      52103007 50,310,266.00       743.00         5887  Traditional
# 4      52103006 50,310,265.00       339.00         7902  Traditional
# ...         ...           ...          ...          ...          ...
# 39172  59500015 59,912,265.00         0.00        44865        Urban
# 39173  59500103 59,914,036.00       540.00        39704        Urban
# 39174  59500049 59,915,062.00         0.00        52055        Urban
# 39175  59500063 59,911,731.00        78.00        41788        Urban
# 39176  59500018 59,912,077.00         0.00        31477        Urban
#
#                        EA_TYPE  econ_status  houses2011 Black_Afri White  \
# 0      Traditional residential  Non_Wealthy      131.00        558     0
# 1      Traditional residential  Non_Wealthy      167.00        713     0
# 2      Traditional residential  Non_Wealthy      135.00        443     0
# 3      Traditional residential  Non_Wealthy      154.00        740     0
# 4      Traditional residential  Non_Wealthy       92.00        339     0
# ...                        ...          ...         ...        ...   ...
# 39172                   Vacant          NaN        0.00        NaN   NaN
# 39173           Small holdings      Wealthy      180.00        NaN   NaN
# 39174       Formal residential          NaN        0.00        NaN   NaN
# 39175     Informal residential  Non_Wealthy       26.00        NaN   NaN
# 39176                   Vacant          NaN        0.00        NaN   NaN
#
#       Coloured Indian_or Other  area_km2  sal_dense  log_density
# 0            0         1     0      6.07      92.05         4.53
# 1            0         0     0      3.90     182.78         5.21
# 2            0         0     0      1.93     229.94         5.44
# 3            1         1     1      1.71     435.35         6.08
# 4            0         0     0      4.05      83.61         4.44
# ...        ...       ...   ...       ...        ...          ...
# 39172      NaN       NaN   NaN      0.52       0.00         0.00
# 39173      NaN       NaN   NaN      4.06     133.14         4.90
# 39174      NaN       NaN   NaN      0.02       0.00         0.00
# 39175      NaN       NaN   NaN      0.54     144.44         4.98
# 39176      NaN       NaN   NaN      0.18       0.00         0.00
#
# [39177 rows x 16 columns]

# %%
sal_wards['log_density'].describe()
# Out:
# count   39,177.00
# mean         7.40
# std          2.50
# min          0.00
# 25%          6.28
# 50%          8.11
# 75%          9.14
# max         13.40
# Name: log_density, dtype: float64

# %%
sal_wards['ward2023_pop'] = pd.to_numeric(sal_wards['ward2023_pop'], errors='coerce')
sal_wards['sal2011_pop']= pd.to_numeric(sal_wards['sal2011_pop'], errors='coerce')

# %%
sal_wards[sal_wards.duplicated(subset='EA_CODE', keep=False)]
sal_wards = sal_wards.drop_duplicates(subset='EA_CODE', keep='first')

# %%
#Calculating proportion of SAL pop within Ward pop

ward2011_sum = sal_wards.groupby('WardID', as_index=False)['sal2011_pop'].sum()
ward2011_sum = ward2011_sum.rename(columns={'sal2011_pop': 'ward2011_sum'})
sal_wards = sal_wards.merge(
    ward2011_sum,
    on='WardID',
    how='left'
)


sal_wards['share2011']=sal_wards['sal2011_pop']/sal_wards['ward2011_sum']

# %%
sal_wards['share2011'].describe()
# Out:
# count   38,380.00
# mean         0.04
# std          0.04
# min          0.00
# 25%          0.02
# 50%          0.02
# 75%          0.05
# max          0.60
# Name: share2011, dtype: float64

# %%
#SAL weights based on density and area

# %%
# gtype_growth = sal_wards.groupby('EA_TYPE').agg(
#     pop2011=('ward2011_sum','sum'),
#     pop2023=('ward2023_pop','sum')
# ).reset_index()


# gtype_growth['growth_ratio'] = gtype_growth['pop2023'] / gtype_growth['pop2011']

# weights_dict = dict(zip(gtype_growth['EA_TYPE'], gtype_growth['growth_ratio']))
# sal_wards['gweight'] = sal_wards['EA_TYPE'].map(weights_dict)

# %%
# sal_wards['gweight'].describe()

# %%
sal_wards['dasym_weight']= sal_wards['share2011']*sal_wards['log_density']
sal_wards['dasym_weight'] = sal_wards['dasym_weight']/sal_wards.groupby('WardID')['dasym_weight'].transform('sum')

# %%
sal_wards['dasym_weight'].describe()
# Out:
# count   38,380.00
# mean         0.04
# std          0.04
# min          0.00
# 25%          0.01
# 50%          0.02
# 75%          0.05
# max          0.59
# Name: dasym_weight, dtype: float64

# %%
#Estimating 2023 SAL population based on weights and 2023 ward level counts
sal_wards['sal2023_est'] = sal_wards['dasym_weight']* sal_wards['ward2023_pop']

# %%
#calculating growth rate using 2011 counts and 2023 estimate

sal_wards['growth_rate'] = ((sal_wards['sal2023_est'] / sal_wards['sal2011_pop'])**(1/12)) - 1

# %%
#Readjusting 2026 predictions to stay within total population margins and account for sprawl from one SAL into another
#wards['Total'] = pd.to_numeric(wards['Total'], errors='coerce')
#totals2011 = sal_wards['sal2011_pop'].sum()
#totals2023 = wards['Total'].sum()

#annual_growth = ((totals2023 / totals2011)**(1/12)) 

#target_2026 = totals2023 * (( annual_growth)**3)

#sal_wards['share2023'] = sal_wards['sal2023_est'] / totals2023

#sal_wards['sal2026_pred'] = sal_wards['share2023'] * target_2026

# %%
sal_wards['ward2023_pop'].describe()
# Out:
# count    38,380.00
# mean     27,492.23
# std      19,153.58
# min       1,444.00
# 25%      11,209.00
# 50%      23,593.00
# 75%      37,831.00
# max     126,728.00
# Name: ward2023_pop, dtype: float64

# %%
sal_wards['sal2023_est'].describe()
# Out:
# count   38,380.00
# mean       717.13
# std        513.69
# min          0.00
# 25%        351.65
# 50%        664.61
# 75%        992.98
# max     14,386.96
# Name: sal2023_est, dtype: float64

# %%
#sal_wards['sal2026_pred'].describe()

# %%
#sal_wards['sal2026_pred'].sum()

# %%
sal_wards['sal2023_est'].sum()
# Out:
# np.float64(27523308.0)

# %%
wards['ward2023_pop'] = pd.to_numeric(wards['Total'], errors='coerce')

# %%
wards['ward2023_pop'].sum()
# Out:
# np.int64(27523308)

# %%
sal_wards['sal2023_est'].sum()-wards['ward2023_pop'].sum()
# Out:
# np.float64(0.0)

# %%
sal_wards[['sal2011_pop','sal2023_est', ]].sum()
# Out:
# sal2011_pop   24,694,905.00
# sal2023_est   27,523,308.00
# dtype: float64

# %%
sal_wards['EA_CODE'] = sal_wards['EA_CODE'].astype('Int64')   # or str if needed

# %%
sal_wards
# Out:
#          WardID   EA_CODE  sal2011_pop  ward2023_pop     EA_GTYPE  \
# 0      52103007  50310272       559.00          5887  Traditional
# 1      52103007  50310271       713.00          5887  Traditional
# 2      52103007  50310262       443.00          5887  Traditional
# 3      52103007  50310266       743.00          5887  Traditional
# 4      52103006  50310265       339.00          7902  Traditional
# ...         ...       ...          ...           ...          ...
# 38375  59500015  59912265         0.00         44865        Urban
# 38376  59500103  59914036       540.00         39704        Urban
# 38377  59500049  59915062         0.00         52055        Urban
# 38378  59500063  59911731        78.00         41788        Urban
# 38379  59500018  59912077         0.00         31477        Urban
#
#                        EA_TYPE  econ_status  houses2011 Black_Afri White  \
# 0      Traditional residential  Non_Wealthy      131.00        558     0
# 1      Traditional residential  Non_Wealthy      167.00        713     0
# 2      Traditional residential  Non_Wealthy      135.00        443     0
# 3      Traditional residential  Non_Wealthy      154.00        740     0
# 4      Traditional residential  Non_Wealthy       92.00        339     0
# ...                        ...          ...         ...        ...   ...
# 38375                   Vacant          NaN        0.00        NaN   NaN
# 38376           Small holdings      Wealthy      180.00        NaN   NaN
# 38377       Formal residential          NaN        0.00        NaN   NaN
# 38378     Informal residential  Non_Wealthy       26.00        NaN   NaN
# 38379                   Vacant          NaN        0.00        NaN   NaN
#
#       Coloured Indian_or Other  area_km2  sal_dense  log_density  \
# 0            0         1     0      6.07      92.05         4.53
# 1            0         0     0      3.90     182.78         5.21
# 2            0         0     0      1.93     229.94         5.44
# 3            1         1     1      1.71     435.35         6.08
# 4            0         0     0      4.05      83.61         4.44
# ...        ...       ...   ...       ...        ...          ...
# 38375      NaN       NaN   NaN      0.52       0.00         0.00
# 38376      NaN       NaN   NaN      4.06     133.14         4.90
# 38377      NaN       NaN   NaN      0.02       0.00         0.00
# 38378      NaN       NaN   NaN      0.54     144.44         4.98
# 38379      NaN       NaN   NaN      0.18       0.00         0.00
#
#        ward2011_sum  share2011  dasym_weight  sal2023_est  growth_rate
# 0          7,387.00       0.08          0.07       391.87        -0.03
# 1          7,387.00       0.10          0.10       574.86        -0.02
# 2          7,387.00       0.06          0.06       372.82        -0.01
# 3          7,387.00       0.10          0.12       698.41        -0.01
# 4          8,923.00       0.04          0.03       272.53        -0.02
# ...             ...        ...           ...          ...          ...
# 38375     33,583.00       0.00          0.00         0.00          NaN
# 38376     33,248.00       0.02          0.01       474.30        -0.01
# 38377     41,652.00       0.00          0.00         0.00          NaN
# 38378     36,133.00       0.00          0.00        58.28        -0.02
# 38379     39,518.00       0.00          0.00         0.00          NaN
#
# [38380 rows x 21 columns]

# %%
import tabulate
print(sal_wards.head().to_markdown(index=False, floatfmt=",.2f"))
# Out:
# |   WardID |   EA_CODE |   sal2011_pop |   ward2023_pop | EA_GTYPE    | EA_TYPE                 | econ_status   |   houses2011 |   Black_Afri |   White |   Coloured |   Indian_or |   Other |   area_km2 |   sal_dense |   log_density |   ward2011_sum |   share2011 |   dasym_weight |   sal2023_est |   growth_rate |
# |---------:|----------:|--------------:|---------------:|:------------|:------------------------|:--------------|-------------:|-------------:|--------:|-----------:|------------:|--------:|-----------:|------------:|--------------:|---------------:|------------:|---------------:|--------------:|--------------:|
# | 52103007 |  50310272 |        559.00 |           5887 | Traditional | Traditional residential | Non_Wealthy   |       131.00 |          558 |       0 |          0 |           1 |       0 |       6.07 |       92.05 |          4.53 |       7,387.00 |        0.08 |           0.07 |        391.87 |         -0.03 |
# | 52103007 |  50310271 |        713.00 |           5887 | Traditional | Traditional residential | Non_Wealthy   |       167.00 |          713 |       0 |          0 |           0 |       0 |       3.90 |      182.78 |          5.21 |       7,387.00 |        0.10 |           0.10 |        574.86 |         -0.02 |
# | 52103007 |  50310262 |        443.00 |           5887 | Traditional | Traditional residential | Non_Wealthy   |       135.00 |          443 |       0 |          0 |           0 |       0 |       1.93 |      229.94 |          5.44 |       7,387.00 |        0.06 |           0.06 |        372.82 |         -0.01 |
# | 52103007 |  50310266 |        743.00 |           5887 | Traditional | Traditional residential | Non_Wealthy   |       154.00 |          740 |       0 |          1 |           1 |       1 |       1.71 |      435.35 |          6.08 |       7,387.00 |        0.10 |           0.12 |        698.41 |         -0.01 |
# | 52103006 |  50310265 |        339.00 |           7902 | Traditional | Traditional residential | Non_Wealthy   |        92.00 |          339 |       0 |          0 |           0 |       0 |       4.05 |       83.61 |          4.44 |       8,923.00 |        0.04 |           0.03 |        272.53 |         -0.02 |

# %%
gtype_summary = sal_wards.groupby('EA_TYPE').agg(
    pop2011=('sal2011_pop','sum'),
    pop2023=('sal2023_est','sum'),
).reset_index()

gtype_summary['growth_rate_2011_2023'] = (
    ((gtype_summary['pop2023'] / gtype_summary['pop2011']) ** (1/12) - 1)*100
)

# %%
sal_wards['sal_dense'].describe()
# Out:
# count    38,380.00
# mean      7,094.11
# std      12,762.57
# min           0.00
# 25%         547.08
# 50%       3,315.59
# 75%       9,331.02
# max     662,594.71
# Name: sal_dense, dtype: float64

# %%
gtype_summary
# Out:
#                        EA_TYPE      pop2011      pop2023  \
# 0   Collective living quarters   341,825.00   286,715.64
# 1                   Commercial   354,128.00   251,390.16
# 2                        Farms   464,324.00   239,160.98
# 3           Formal residential 8,060,534.00 7,759,037.23
# 4                   Industrial   206,049.00   142,472.80
# 5         Informal residential 1,849,126.00 2,486,815.99
# 6         Parks and recreation    21,996.00    11,008.77
# 7               Small holdings   281,723.00   221,942.46
# 8                     Township 7,677,887.00 9,898,537.73
# 9      Traditional residential 5,162,867.00 5,965,878.56
# 10                      Vacant   274,446.00   260,347.69
#
#     growth_rate_2011_2023
# 0                   -1.45
# 1                   -2.82
# 2                   -5.38
# 3                   -0.32
# 4                   -3.03
# 5                    2.50
# 6                   -5.60
# 7                   -1.97
# 8                    2.14
# 9                    1.21
# 10                  -0.44

# %%
#print(gtype_summary.to_markdown(index=False, floatfmt=",.2f"))

# %%
sal_map = sal.merge(
    sal_wards,
    on='EA_CODE',
    how='left'
)
# Out:
# C:\Users\Tess\AppData\Local\Temp\ipykernel_16616\999446382.py:1: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation.
#   sal_map = sal.merge(

# %%
sal_wards['sal2023_est'].describe()
# Out:
# count   38,380.00
# mean       717.13
# std        513.69
# min          0.00
# 25%        351.65
# 50%        664.61
# 75%        992.98
# max     14,386.96
# Name: sal2023_est, dtype: float64

# %%
import mapclassify
import matplotlib.pyplot as plt
import matplotlib as mpl

fig, axes = plt.subplots(1, 2, figsize=(16,10))

provinces = sal_map['PR_NAME'].unique()

# consistent bins
bin_edges = [0, 500,1000, 2500, 5000, 10000, 15000]

cmap = mpl.cm.viridis_r

for i, prov in enumerate(provinces):

    subset = sal_map[sal_map['PR_NAME'] == prov].copy()
    subset = subset[subset['sal2023_est'].notna()]  # drop missing

    subset.plot(
        column='sal2023_est',
        cmap=cmap,
        scheme='UserDefined',
        classification_kwds={'bins': bin_edges},
        legend=False,
        ax=axes[i]
    )

    axes[i].set_title(prov, fontsize=14)
    axes[i].axis('off')

# ---- shared colorbar (fixed mapping) ----
norm = mpl.colors.BoundaryNorm(bin_edges, ncolors=cmap.N)
sm = mpl.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])

cbar_ax = fig.add_axes([0.48, 0.25, 0.02, 0.5])
cbar = fig.colorbar(sm, cax=cbar_ax)
cbar.set_label("Population")

plt.suptitle("SAL 2023 Estimate Count")

output_file = "images/newpred/pop2023estimate.png"
plt.savefig(output_file, dpi=300, bbox_inches='tight')

plt.show()

print(f"Map saved to {output_file}")
# Out:
# Map saved to pop2023estimate.png

# %%
sal_map['dense_2023']= sal_map['sal2023_est']/sal_map['area_km2']

# %%
sal_map['dense_2023'].describe()
# Out:
# count    34,781.00
# mean      8,110.79
# std      14,173.21
# min           0.00
# 25%         500.95
# 50%       3,207.72
# 75%      11,237.54
# max     621,632.68
# Name: dense_2023, dtype: float64

# %%
sal_map['log_density'] = np.log1p(sal_map['dense_2023'])

# %%
import mapclassify
import matplotlib.pyplot as plt
import matplotlib as mpl
fig, axes = plt.subplots(1, 2, figsize=(16,10))

provinces = sal_map['PR_NAME'].unique()

for i, prov in enumerate(provinces):
    
    subset = sal_map[sal_map['PR_NAME'] == prov].copy()
    
    # compute quintile breaks
    subset.plot(
        column='log_density',
        cmap='viridis_r',
        legend=False,
        scheme='Quantiles',
        k=6,
        ax=axes[i]
    )
        
    axes[i].set_title(prov, fontsize=14)
    axes[i].axis('off')

# 🔥 Create shared colorbar in the middle
norm = mpl.colors.Normalize(
    vmin=sal_map['log_density'].min(),
    vmax=sal_map['log_density'].max()
)
sm = mpl.cm.ScalarMappable(cmap='viridis_r', norm=norm)
sm.set_array([])

# [left, bottom, width, height] → tweak these numbers if needed
cbar_ax = fig.add_axes([0.48, 0.25, 0.02, 0.5])  

cbar = fig.colorbar(sm, cax=cbar_ax)
cbar.set_label("Population Density (normalized) per km sq")
plt.suptitle("SAL 2023 Density (Log)")
output_file = "images/newpred/popdensity.png"
plt.savefig(output_file, dpi=300, bbox_inches='tight')

plt.show()

print(f"Map saved to {output_file}")
# Out:
# Map saved to popdensity.png

# %%
sal_wards.to_csv('data/pop_pred_final.csv', index=False)

# %%
sal_map = sal_map.to_crs(sal_with_ward.crs)

# %%
import mapclassify
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.patches import Rectangle

# -------------------------
# FILTER DATA
# -------------------------
gauteng = sal_map[sal_map['PR_NAME'].str.contains("Gauteng", case=False, na=False)].copy()

jhb = gauteng[gauteng['MN_NAME'].str.contains("Johannesburg", case=False, na=False)]

# -------------------------
# FIGURE (Joburg bigger)
# -------------------------
fig, axes = plt.subplots(
    1, 2,
    figsize=(16,10),
    gridspec_kw={'width_ratios': [1, 2]}  # Joburg panel bigger
)

# -------------------------
# LEFT: GAUTENG (context)
# -------------------------
gauteng.plot(
    column='log_density',
    cmap='viridis_r',
    legend=False,
    scheme='Quantiles',
    k=8,
    ax=axes[0]
)

# Add rectangular outline for Johannesburg
xmin, ymin, xmax, ymax = jhb.total_bounds
pad_x = (xmax - xmin) * 0.02  # slight padding
pad_y = (ymax - ymin) * 0.02

rect = Rectangle(
    (xmin - pad_x, ymin - pad_y),
    (xmax - xmin) + 2*pad_x,
    (ymax - ymin) + 2*pad_y,
    linewidth=2,
    edgecolor='red',
    facecolor='none'
)
axes[0].add_patch(rect)

axes[0].set_title("Gauteng (Context)", fontsize=12)
axes[0].axis('off')

# -------------------------
# RIGHT: JOHANNESBURG (zoom)
# -------------------------
jhb.plot(
    column='log_density',
    cmap='viridis_r',
    legend=False,
    scheme='Quantiles',
    k=8,
    ax=axes[1]
)

axes[1].set_title("Johannesburg Population Density ", fontsize=14)
axes[1].axis('off')

# -------------------------
# SHARED COLORBAR
# -------------------------
norm = mpl.colors.Normalize(
    vmin=sal_map['log_density'].min(),
    vmax=sal_map['log_density'].max()
)

sm = mpl.cm.ScalarMappable(cmap='viridis_r', norm=norm)
sm.set_array([])

cbar = fig.colorbar(
    sm,
    ax=axes,
    fraction=0.02,
    pad=0.04
)
cbar.set_label("Population Density (normalized) per km sq")

# -------------------------
# SAVE
# -------------------------
output_file = "images/newpred/gauteng_joburg_sidebyside_rect.png"
plt.savefig(output_file, dpi=300, bbox_inches='tight')

plt.show()
print(f"Map saved to {output_file}")
# Out:
# Map saved to gauteng_joburg_sidebyside_rect.png

# %%
sal_wards['sal_dense'].describe()
# Out:
# count    38,380.00
# mean      7,094.11
# std      12,762.57
# min           0.00
# 25%         547.08
# 50%       3,315.59
# 75%       9,331.02
# max     662,594.71
# Name: sal_dense, dtype: float64

# %%
print(sal_with_ward.crs)
# Out:
# EPSG:32735

# %%
print(sal_wards['share2011'].describe().to_markdown(index=False, floatfmt=",.2f"))
# Out:
# |   share2011 |
# |------------:|
# |   38,380.00 |
# |        0.04 |
# |        0.04 |
# |        0.00 |
# |        0.02 |
# |        0.02 |
# |        0.05 |
# |        0.60 |

# %%
sal_wards[sal_wards['sal_dense'] >100000].sort_values('area_km2')
# Out:
#          WardID   EA_CODE  sal2011_pop  ward2023_pop EA_GTYPE  \
# 32761  79900092  79912522       445.00         18865    Urban
# 14059  59500022  59913668     1,306.00         21794    Urban
# 12534  59500032  59912963       462.00         14371    Urban
# 12590  59500026  59912424       636.00         26827    Urban
# 26006  79800123  79813410       502.00         24539    Urban
# ...         ...       ...          ...           ...      ...
# 12607  59500026  59912414     1,723.00         26827    Urban
# 26061  79800062  79812267     3,095.00         14993    Urban
# 26057  79800062  79812266     2,206.00         14993    Urban
# 26379  79800061  79813441     2,967.00         13977    Urban
# 26062  79800063  79813430     3,688.00         76487    Urban
#
#                           EA_TYPE  econ_status  houses2011 Black_Afri White  \
# 32761  Collective living quarters  Non_Wealthy        4.00        416    20
# 14059                    Township  Non_Wealthy       10.00       1304     0
# 12534          Formal residential      Wealthy       10.00        434     1
# 12590          Formal residential      Wealthy        4.00        603     5
# 26006          Formal residential      Wealthy        3.00        502     0
# ...                           ...          ...         ...        ...   ...
# 12607          Formal residential      Wealthy       23.00       1407   194
# 26061          Formal residential      Wealthy       20.00       3068     6
# 26057          Formal residential      Wealthy       23.00       2188     2
# 26379  Collective living quarters  Non_Wealthy       11.00       2957     6
# 26062          Formal residential      Wealthy       18.00       3582    16
#
#       Coloured Indian_or Other  area_km2  sal_dense  log_density  \
# 32761        9         0     0      0.00 287,063.27        12.57
# 14059        2         0     0      0.00 662,594.71        13.40
# 12534       17         0    10      0.00 193,206.77        12.17
# 12590        8        20     0      0.00 241,602.60        12.40
# 26006        0         0     0      0.00 189,608.54        12.15
# ...        ...       ...   ...       ...        ...          ...
# 12607       58        60     4      0.02 101,856.19        11.53
# 26061       15         6     0      0.02 151,038.37        11.93
# 26057        7         1     8      0.02 100,505.80        11.52
# 26379        2         1     1      0.02 124,315.56        11.73
# 26062       35        53     2      0.03 116,065.25        11.66
#
#        ward2011_sum  share2011  dasym_weight  sal2023_est  growth_rate
# 32761     45,971.00       0.01          0.01       232.52        -0.05
# 14059     32,132.00       0.04          0.06     1,225.26        -0.01
# 12534     30,563.00       0.02          0.02       270.92        -0.04
# 12590     48,180.00       0.01          0.02       420.84        -0.03
# 26006     35,377.00       0.01          0.02       398.63        -0.02
# ...             ...        ...           ...          ...          ...
# 12607     48,180.00       0.04          0.04     1,060.65        -0.04
# 26061     31,813.00       0.10          0.10     1,520.13        -0.06
# 26057     31,813.00       0.07          0.07     1,046.49        -0.06
# 26379     13,612.00       0.22          0.27     3,726.70         0.02
# 26062     33,515.00       0.11          0.11     8,629.82         0.07
#
# [112 rows x 21 columns]

# %%
cols = ['sal2023_est', 'sal2011_pop', 'growth_rate', 
        'dasym_weight', 'share2011', 'log_density']

summary = sal_wards[cols].describe()

print(gtype_summary.to_markdown(floatfmt=",.3f"))
# Out:
# |    | EA_TYPE                    |       pop2011 |       pop2023 |   growth_rate_2011_2023 |
# |---:|:---------------------------|--------------:|--------------:|------------------------:|
# |  0 | Collective living quarters |   341,825.000 |   286,715.642 |                  -1.454 |
# |  1 | Commercial                 |   354,128.000 |   251,390.162 |                  -2.815 |
# |  2 | Farms                      |   464,324.000 |   239,160.978 |                  -5.379 |
# |  3 | Formal residential         | 8,060,534.000 | 7,759,037.227 |                  -0.317 |
# |  4 | Industrial                 |   206,049.000 |   142,472.801 |                  -3.028 |
# |  5 | Informal residential       | 1,849,126.000 | 2,486,815.992 |                   2.500 |
# |  6 | Parks and recreation       |    21,996.000 |    11,008.766 |                  -5.605 |
# |  7 | Small holdings             |   281,723.000 |   221,942.461 |                  -1.968 |
# |  8 | Township                   | 7,677,887.000 | 9,898,537.728 |                   2.140 |
# |  9 | Traditional residential    | 5,162,867.000 | 5,965,878.557 |                   1.212 |
# | 10 | Vacant                     |   274,446.000 |   260,347.687 |                  -0.439 |

# %%
print(sal_wards.loc[sal_wards['growth_rate'].idxmin()].to_markdown(index=True, floatfmt=",.2f"))
# Out:
# |              | 36132                  |
# |:-------------|:-----------------------|
# | WardID       | 52805012               |
# | EA_CODE      | 58810097               |
# | sal2011_pop  | 1.0                    |
# | ward2023_pop | 10170                  |
# | EA_GTYPE     | Traditional            |
# | EA_TYPE      | Vacant                 |
# | econ_status  | Non_Residential        |
# | houses2011   | 15.0                   |
# | Black_Afri   | 0                      |
# | White        | 0                      |
# | Coloured     | 0                      |
# | Indian_or    | 0                      |
# | Other        | 0                      |
# | area_km2     | 77.77991507307826      |
# | sal_dense    | 0.012856789558852671   |
# | log_density  | 0.012774842675117377   |
# | ward2011_sum | 9292.0                 |
# | share2011    | 0.00010761945759793371 |
# | dasym_weight | 3.2707980640609965e-07 |
# | sal2023_est  | 0.0033264016311500334  |
# | growth_rate  | -0.37841877158855086   |

# %%
sal_wards.loc[sal_wards['sal2023_est'].idxmax()]
# Out:
# WardID             79800040
# EA_CODE            79812990
# sal2011_pop       11,717.00
# ward2023_pop          32678
# EA_GTYPE              Urban
# EA_TYPE            Township
# econ_status     Non_Wealthy
# houses2011            26.00
# Black_Afri            11662
# White                     3
# Coloured                 16
# Indian_or                 7
# Other                    29
# area_km2               0.47
# sal_dense         24,754.07
# log_density           10.12
# ward2011_sum      27,641.00
# share2011              0.42
# dasym_weight           0.44
# sal2023_est       14,386.96
# growth_rate            0.02
# Name: 28532, dtype: object
