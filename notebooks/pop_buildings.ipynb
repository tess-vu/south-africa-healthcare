# %%
import geopandas as gpd
import pandas as pd

# Load population polygons (SAL / tracts / wards)
pop = gpd.read_file("../pop_pred_final.csv")

# Load building footprints
bldg = gpd.read_file("../../buildings/open_buildings_v3_polygons_your_own_wkt_polygon_2.csv")

# Quick check
print(pop.head())
print(bldg.head())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\envs\urbanspatial\lib\encodings\cp1252.py:14, in Codec.decode(self, input, errors)
#      12     return codecs.charmap_encode(input,errors,encoding_table)
# ---> 14 def decode(self,input,errors='strict'):
#      15     return codecs.charmap_decode(input,errors,decoding_table)
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 8
#       5 pop = gpd.read_file("../pop_pred_final.csv")
#       7 # Load building footprints
# ----> 8 bldg = gpd.read_file("../../buildings/open_buildings_v3_polygons_your_own_wkt_polygon_2.csv")
#      10 # Quick check
#      11 print(pop.head())
#
# ...
